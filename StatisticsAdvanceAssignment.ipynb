# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakGangwar17/DataScienceAssignments/blob/main/StatisticsAdvanceAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Answer 1:-
# PDF- The full form of pdf is probability density function . It is used for continuos random variable.
# It shows how likely the var is occuring within specific range .
# It show the probability of range of the values.

# %% [markdown]
# Answer 2:-
# There are mainly three type of probability distribution -
# 1. pdf(probability density function)
# 2. pmf(probability mass function)
# 3.cdf(cumulative distribution function)

# %% [markdown]
# Answer 4:-
# The result of every trail is binary.
# In this there are n sequencial trial.
# It consist of group of bernauli distrution.
# Ex- Tossing a coin 10 times and finding probability of head.
# Probability of winning of team A in   in series of matches.

# %% [markdown]
# Answer 5:-

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 1000  # Sample size
p = 0.4   # Probability of success

# Generate random sample from binomial distribution
sample = np.random.binomial(1, p, size=n)

# Plot histogram
plt.hist(sample, bins=[-0.5, 0.5, 1.5], edgecolor='black', alpha=0.7)
plt.xlabel('Outcome (0: Failure, 1: Success)')
plt.ylabel('Frequency')
plt.title('Histogram of Binomial Distribution (n=1000, p=0.4)')
plt.xticks([0, 1], ['Failure', 'Success'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Answer 7:-
# In binomial distribuition we find the probability of n sequential event .
# Int poisson we find the probabilty of no. of events occuring in fixed duration of time.

# %% [markdown]
# Answer 9:-
# Binomial Distribution-
# Mean= n*p
# variance=n*p*(1-p)
# where n is equal to no of sequence.
# p is probabilty  of succes
# and 1-p is probability of failure
#
#
# Poisson Distribution-
# Mean= lambda * t
# variance =lambda *t
# lambda= expected no. of event occur in pre unit time

# %% [markdown]
# Answer 10:-
# The least data is appeared in third devation from the mean in both side.
